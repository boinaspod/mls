# %%
import pandas as pd
import numpy as np
from scipy.stats import poisson 
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
tabla = pd.read_html('https://mexico.as.com/resultados/futbol/mls/clasificacion/')
jornadas = pd.read_html('https://mexico.as.com/resultados/futbol/mls/calendario/')
jornadas[5].Resultado[12]='0 - 0'
jornadas[5].Resultado[13]='0 - 0'
jornadas[15].Resultado[14]='0 - 0'
jornadas[22].Resultado[13]='0 - 0'

jornadascompletas=22

j=list(range(0,jornadascompletas))

resultado_local=pd.DataFrame()
resultado_visita=pd.DataFrame()
for i in j:
    resultado=jornadas[i].Resultado.str.split("-", n = 1, expand = True).astype(int)
    resultado_local[i]=pd.Series(resultado[0])
    resultado_visita[i]=pd.Series(resultado[1])

resultado_local=resultado_local.fillna(0)
resultado_visita=resultado_visita.fillna(0)
resultado_local.to_csv('mls_resultado_local.csv')
resultado_visita.to_csv('mls_resultado_visita.csv')

equipo_local=pd.DataFrame()
equipo_visita=pd.DataFrame()
for i in list(range(0,jornadascompletas)):
    equipo_local[i]=jornadas[i]['Equipo local']
    equipo_visita[i]=jornadas[i]['Equipo visitante']

equipo_local=equipo_local.fillna(0)
equipo_visita=equipo_visita.fillna(0)
equipo_local.to_csv('mls_equipo_local.cvs',sep=',')
equipo_visita.to_csv('mls_equipo_visita.cvs',sep=',')

for i in j:
    pd.DataFrame({'equipo local':equipo_local[i],'goles local':resultado_local[i],'goles visita':resultado_visita[i],'equipo visita':equipo_visita[i]}).to_csv('mls_jornada{}.csv'.format(i),index=False)

suma_goles_local_jornada=resultado_local.sum()
suma_goles_visita_jornada=resultado_visita.sum()
dif_goles=suma_goles_local_jornada-suma_goles_visita_jornada

este=tabla[0]
oeste=tabla[1]
club1=este.Equipo.str.split("  ", n = 1, expand = True)
club1=club1[1].str.split("  ", n = 1, expand = True)
club2=oeste.Equipo.str.split("  ", n = 1, expand = True)
club2=club2[1].str.split("  ", n = 1, expand = True)
club_este=club1[0]
club_oeste=club2[0]
este['Equipo']=club_este
oeste['Equipo']=club_oeste

mls = pd.DataFrame()
mls = pd.concat([este, oeste])
mls.reset_index(level=None, drop=True, inplace=True, col_level=0, col_fill='')

local=jornadas[jornadascompletas]['Equipo local'].tolist()
visita=jornadas[jornadascompletas]['Equipo visitante'].tolist()
equipos_list=mls['Equipo'].tolist()
mls
# Out:
#                     Equipo  Pts.  PJ  PG  PE  PP  GF  GC  Dif.
# 0       Philadelphia Union    48  25  13   9   3  45  19    26
# 1          Montreal Impact    43  25  13   4   8  43  41     2
# 2            New York City    42  24  12   6   6  45  27    18
# 3       New York Red Bulls    37  25  10   7   8  38  31     7
# 4            Columbus Crew    34  24   8  10   6  32  27     5
# 5             Orlando City    33  25   9   6  10  28  36    -8
# 6           Inter Miami CF    33  25   9   6  10  32  41    -9
# 7   New England Revolution    33  24   8   9   7  36  34     2
# 8            FC Cincinnati    33  25   8   9   8  42  45    -3
# 9             Chicago Fire    30  25   8   6  11  28  34    -6
# 10            Charlotte FC    29  25   9   2  14  30  39    -9
# 11              Toronto FC    29  25   8   5  12  37  43    -6
# 12       Atlanta United FC    29  24   7   8   9  33  36    -3
# 13               DC United    22  24   6   4  14  28  48   -20
# 14          Los Angeles FC    54  24  17   3   4  53  24    29
# 15               Austin FC    48  25  14   6   5  54  34    20
# 16               FC Dallas    39  26  10   9   7  38  28    10
# 17     Minnesota United FC    35  24  10   5   9  38  34     4
# 18          Real Salt Lake    34  24   9   7   8  31  33    -2
# 19      Los Angeles Galaxy    33  24  10   3  11  37  34     3
# 20            Nashville SC    33  25   8   9   8  33  34    -1
# 21        Portland Timbers    33  26   7  12   7  42  40     2
# 22        Seattle Sounders    32  24  10   2  12  31  29     2
# 23         Colorado Rapids    31  24   8   7   9  35  37    -2
# 24     Vancouver Whitecaps    30  25   8   6  11  29  44   -15
# 25          Houston Dynamo    25  25   7   4  14  31  42   -11
# 26    San José Earthquakes    24  25   5   9  11  40  53   -13
# 27    Sporting Kansas City    23  26   6   5  15  26  48   -22

# %%
resultado=jornadas[jornadascompletas].Resultado.str.split("-", n = 1, expand = True).astype(int)
resultado.columns=['Local','Visita']
tamañojornada=len(local)

stats_mls=mls.describe()
mls_av=pd.DataFrame()
mls_av['mean GF']=mls['GF'][:]/stats_mls['PJ'][1]
mls_av['mean GC']=mls['GC'][:]/stats_mls['PJ'][1]
mls_av['ataque']=mls_av['mean GF']/(stats_mls['GF'][1]/stats_mls['PJ'][1])
mls_av['defensa']=mls_av['mean GC']/(stats_mls['GC'][1]/stats_mls['PJ'][1])
stats_mls_av=mls_av.describe()

# %%
matrix_goles=pd.DataFrame()
ind=list(range(0,len(equipos_list)))
for i in ind:
    matrix_goles[equipos_list[ind[i]]]=mls_av['ataque'][ind[i]]*mls_av['defensa'][:]*stats_mls_av['mean GF'][1]

matrix_goles.columns=equipos_list
matrix_goles.index=equipos_list

GFx_local=np.diag(matrix_goles[local].loc[visita])
GFx_visita=np.diag(matrix_goles[visita].loc[local])

k=[0,1,2,3,4,5]
P_home=pd.DataFrame()
P_away=pd.DataFrame()
mu=GFx_local
mu2=GFx_visita

for i in k:
    P_home[i]=poisson.pmf(k[i],mu)
    P_away[i]=poisson.pmf(k[i],mu2)

P_home.index=local
P_away.index=visita

g=pd.DataFrame()
j=list(range(0,tamañojornada))

for i in j: 
    tabla=pd.DataFrame({local[i]:P_home.iloc[i].tolist(),visita[i]:P_away.iloc[i].tolist()})
    tabla.to_csv('tabla{}.csv'.format(i),index=False, sep=',')
    p=tabla.idxmax()
    g=pd.concat([g,p])

g=g[0]
Pgoles_home = g[local]
Pgoles_away = g[visita]
Pgoles_home = Pgoles_home[~Pgoles_home.index.duplicated(keep='first')]
Pgoles_away = Pgoles_away[~Pgoles_away.index.duplicated(keep='first')]

tabla=pd.DataFrame()
winlcl=pd.DataFrame()
winvis=pd.DataFrame()
e=pd.DataFrame()

for i in j:
    tabla=pd.read_csv('tabla{}.csv'.format(i))
    empate=pd.Series(tabla.iloc[0][0]*tabla.iloc[0][1]+tabla.iloc[1][0]*tabla.iloc[1][1]+tabla.iloc[2][0]*tabla.iloc[2][1]+tabla.iloc[3][0]*tabla.iloc[3][1]+tabla.iloc[4][0]*tabla.iloc[4][1]+tabla.iloc[5][0]*tabla.iloc[5][1])
    vis=pd.Series(tabla.iloc[0][0]*tabla.iloc[1][1]+tabla.iloc[0][0]*tabla.iloc[2][1]+tabla.iloc[0][0]*tabla.iloc[3][1]+tabla.iloc[0][0]*tabla.iloc[4][1]+tabla.iloc[0][0]*tabla.iloc[5][1]+tabla.iloc[1][0]*tabla.iloc[2][1]+tabla.iloc[1][0]*tabla.iloc[3][1]+tabla.iloc[1][0]*tabla.iloc[4][1]+tabla.iloc[1][0]*tabla.iloc[5][1]+tabla.iloc[2][0]*tabla.iloc[3][1]+tabla.iloc[2][0]*tabla.iloc[4][1]+tabla.iloc[2][0]*tabla.iloc[5][1]+tabla.iloc[3][0]*tabla.iloc[4][1]+tabla.iloc[3][0]*tabla.iloc[5][1]+tabla.iloc[4][0]*tabla.iloc[5][1])
    lcl=pd.Series(tabla.iloc[0][1]*tabla.iloc[1][0]+tabla.iloc[0][1]*tabla.iloc[2][0]+tabla.iloc[0][1]*tabla.iloc[3][0]+tabla.iloc[0][1]*tabla.iloc[4][0]+tabla.iloc[0][1]*tabla.iloc[5][0]+tabla.iloc[1][1]*tabla.iloc[2][0]+tabla.iloc[1][1]*tabla.iloc[3][0]+tabla.iloc[1][1]*tabla.iloc[4][0]+tabla.iloc[1][1]*tabla.iloc[5][0]+tabla.iloc[2][1]*tabla.iloc[3][0]+tabla.iloc[2][1]*tabla.iloc[4][0]+tabla.iloc[2][1]*tabla.iloc[5][0]+tabla.iloc[3][1]*tabla.iloc[4][0]+tabla.iloc[3][1]*tabla.iloc[5][0]+tabla.iloc[4][1]*tabla.iloc[5][0])
    e=pd.concat([e,empate])
    winvis=pd.concat([winvis,vis])
    winlcl=pd.concat([winlcl,lcl])

winvis.index=j
winlcl.index=j
e.index=j
visita_gane=winvis
local_gane=winlcl
empate=e

# %%
probabilidades=pd.DataFrame({'local':local, 'P ganar local':local_gane[0], 'P empate':empate[0], 'P ganar visita':visita_gane[0], 'visita':visita})
probabilidades
# Out:
#                      local  P ganar local  P empate  P ganar visita  \
# 0           Los Angeles FC       0.575651  0.236745        0.179040
# 1      Minnesota United FC       0.398609  0.230282        0.357295
# 2             Chicago Fire       0.329222  0.277455        0.390385
# 3       Philadelphia Union       0.690462  0.185318        0.103304
# 4          Montreal Impact       0.235512  0.212005        0.531523
# 5           Inter Miami CF       0.320232  0.219104        0.440666
# 6             Nashville SC       0.488170  0.247079        0.257373
# 7   New England Revolution       0.444003  0.233874        0.310284
# 8     Sporting Kansas City       0.098536  0.137689        0.689724
# 9                FC Dallas       0.432642  0.260796        0.301628
# 10    San José Earthquakes       0.307314  0.226203        0.451150
# 11               DC United       0.283445  0.256992        0.454024
# 12      New York Red Bulls       0.450960  0.249209        0.292751
# 13            Charlotte FC       0.243587  0.273092        0.479845
#
#                  visita
# 0      Seattle Sounders
# 1      Portland Timbers
# 2     Atlanta United FC
# 3        Houston Dynamo
# 4         New York City
# 5         FC Cincinnati
# 6   Vancouver Whitecaps
# 7            Toronto FC
# 8             Austin FC
# 9    Los Angeles Galaxy
# 10       Real Salt Lake
# 11         Orlando City
# 12      Colorado Rapids
# 13        Columbus Crew

# %%
local_win=probabilidades[resultado['Local'].values>resultado['Visita'].values].index
visita_win=probabilidades[resultado['Local'].values<resultado['Visita'].values].index
empanada=probabilidades[resultado['Local'].values==resultado['Visita'].values].index

# %%
effec_local=probabilidades.loc[local_win.values]
e=np.array(effec_local['P ganar local']>effec_local['P ganar visita'])
e_local=np.count_nonzero(e)/len(e)
print('effectividad pronostico para locales: {} '.format(e_local))
# Out:
# effectividad pronostico para locales: 0.75

# %%
effec_visita=probabilidades.loc[visita_win.values]
e=np.array(effec_visita['P ganar local']<effec_visita['P ganar visita'])
e_visita=np.count_nonzero(e)/len(e)
print('effectividad pronostico para visitantes: {} '.format(e_visita))
# Out:
# effectividad pronostico para visitantes: 0.5

# %%
effect_empate=probabilidades.loc[empanada.values]
e=effect_empate['P ganar local']<effect_empate['P empate']
e2=effect_empate['P empate']>effect_empate['P ganar visita']
res = [i for i, val in enumerate(e) if val]
res2 = [i for i, val in enumerate(e2) if val]
df=pd.DataFrame(res)
df2=pd.DataFrame(res2)
e3=np.array(df.isin(df2))
if len(e3) == 0:
    e_empate = 0
else:
    e_empate = np.count_nonzero(e3)/len(e3)
    
print('effectividad pronostico para empate: {} '.format(e_empate))
# Out:
# effectividad pronostico para empate: 0.0

# %%
effectivo=pd.DataFrame({'local':[e_local], 'visita':[e_visita], 'empate':[e_empate]})
effectivo.to_csv('effect_jornada{}.csv'.format(jornadascompletas))

# %%
jj=list(range(5,jornadascompletas))
eff_local=pd.DataFrame()
eff_visita=pd.DataFrame()
eff_emp=pd.DataFrame()
for i in jj:
    eff=pd.read_csv('effect_jornada{}.csv'.format(i))
    eff_local[i]=eff.local
    eff_visita[i]=eff.visita
    eff_emp[i]=eff.empate

plt.plot(eff_local.loc[0],'-s',label='local')
plt.plot(eff_visita.loc[0],'-*',label='visita')
plt.plot(eff_emp.loc[0],'-ok',label='empate')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), prop={'size': 10}, frameon=False)
plt.title('Pronosticos Liga MLS 2022')
plt.xlabel('Jornadas')
plt.ylabel('Efectividad')
plt.savefig('mls_effectividad_probabilidades.png')
plt.show()

print('Efectividad promedio para locales: {} '.format(eff_local.loc[0].mean()))
print('Efectividad promedio para visitantes: {} '.format(eff_visita.loc[0].mean()))
print('Efectividad promedio para empate: {} '.format(eff_emp.loc[0].mean()))
# Out:
# Efectividad promedio para locales: 0.5821895424836602
# Efectividad promedio para visitantes: 0.7259103641456582
# Efectividad promedio para empate: 0.0

# %%
pronosticoP=pd.DataFrame({'Local':local, 'P GF local':Pgoles_home.values, 'P GF visita':Pgoles_away.values, 'Visita':visita})
pronosticoP
# Out:
#                      Local  P GF local  P GF visita               Visita
# 0           Los Angeles FC         1.0          0.0     Seattle Sounders
# 1      Minnesota United FC         1.0          1.0     Portland Timbers
# 2             Chicago Fire         1.0          1.0    Atlanta United FC
# 3       Philadelphia Union         2.0          0.0       Houston Dynamo
# 4          Montreal Impact         1.0          2.0        New York City
# 5           Inter Miami CF         1.0          1.0        FC Cincinnati
# 6             Nashville SC         1.0          1.0  Vancouver Whitecaps
# 7   New England Revolution         1.0          1.0           Toronto FC
# 8     Sporting Kansas City         0.0          2.0            Austin FC
# 9                FC Dallas         1.0          1.0   Los Angeles Galaxy
# 10    San José Earthquakes         1.0          1.0       Real Salt Lake
# 11               DC United         1.0          1.0         Orlando City
# 12      New York Red Bulls         1.0          1.0      Colorado Rapids
# 13            Charlotte FC         0.0          1.0        Columbus Crew

# %%
local_win=pronosticoP[resultado['Local'].values>resultado['Visita'].values].index
visita_win=pronosticoP[resultado['Local'].values<resultado['Visita'].values].index
empanada=pronosticoP[resultado['Local'].values==resultado['Visita'].values].index

# %%
effec_local=pronosticoP.loc[local_win.values]
e=np.array(effec_local['P GF local']>effec_local['P GF visita'])
e_local_P=np.count_nonzero(e)/len(e)
print('effectividad Poisson para locales: {} '.format(e_local_P))
# Out:
# effectividad Poisson para locales: 0.5

# %%
effec_visita=pronosticoP.loc[visita_win.values]
e=np.array(effec_visita['P GF local']<effec_visita['P GF visita'])
e_visita_P=np.count_nonzero(e)/len(e)
print('effectividad Poisson para visitantes: {} '.format(e_visita_P))
# Out:
# effectividad Poisson para visitantes: 0.5

# %%
effect_empate=pronosticoP.loc[empanada.values]
e=np.array(effect_empate['P GF local']==effect_empate['P GF visita'])
e_empate_P=np.count_nonzero(e)/len(e)
print('effectividad Poisson para empate: {} '.format(e_empate_P))
# Out:
# effectividad Poisson para empate: 0.75

# %%
effectivo=pd.DataFrame({'local':[e_local_P], 'visita':[e_visita_P], 'empate':[e_empate_P]})
effectivo.to_csv('effect_Poisson_jornada{}.csv'.format(jornadascompletas))

# %%
jj=list(range(5,jornadascompletas))
eff_local=pd.DataFrame()
eff_visita=pd.DataFrame()
eff_emp=pd.DataFrame()
for i in jj:
    eff=pd.read_csv('effect_Poisson_jornada{}.csv'.format(i))
    eff_local[i]=eff.local
    eff_visita[i]=eff.visita
    eff_emp[i]=eff.empate

plt.plot(eff_local.loc[0],'-s',label='local')
plt.plot(eff_visita.loc[0],'-*',label='visita')
plt.plot(eff_emp.loc[0],'-ok',label='empate')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), prop={'size': 10}, frameon=False)
plt.title('Pronosticos Poisson Liga MLS 2022')
plt.xlabel('Jornadas')
plt.ylabel('Efectividad')
plt.savefig('mls_effectividad_Poisson.png')
plt.show()

print('Efectividad Poisson promedio para locales: {} '.format(eff_local.loc[0].mean()))
print('Efectividad Poisson promedio para visitantes: {} '.format(eff_visita.loc[0].mean()))
print('Efectividad Poisson promedio para empate: {} '.format(eff_emp.loc[0].mean()))
# Out:
# Efectividad Poisson promedio para locales: 0.2686274509803922
# Efectividad Poisson promedio para visitantes: 0.46106442577030815
# Efectividad Poisson promedio para empate: 0.4872549019607844

# %%
local_cumulativo=np.array(suma_goles_local_jornada)
visita_cumulativo=np.array(suma_goles_visita_jornada)
x=np.cumsum(local_cumulativo)
y=np.cumsum(visita_cumulativo)
z=np.cumsum(local_cumulativo-visita_cumulativo)
X=np.linspace(0, jornadascompletas, num=jornadascompletas).reshape((-1, 1))

plt.plot(x,'s',label='local')
plt.plot(y,'rs',label='visita')
plt.plot(z,'gs',label='diferencia')

model = LinearRegression()
model.fit(X, x)
model = LinearRegression().fit(X, x)
y_pred = model.predict(X)
r_sq = model.score(X, x)
print('Regresión lineal de sumatoria de goles de locales')
print(f"R^2: {r_sq}")
print(f"b: {model.intercept_}")
print(f"m: {model.coef_}")
plt.plot(y_pred,'-b')

model = LinearRegression()
model.fit(X, y)
model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
r_sq = model.score(X, y)
print('\nRegresión lineal de sumatoria de goles de visitantes')
print(f"R^2: {r_sq}")
print(f"b: {model.intercept_}")
print(f"m: {model.coef_}")
plt.plot(y_pred,'-r')

model = LinearRegression()
model.fit(X, z)
model = LinearRegression().fit(X, z)
y_pred = model.predict(X)
r_sq = model.score(X, z)
print('\nRegresión lineal de diferencia de goles por jornada')
print(f"R^2: {r_sq}")
print(f"b: {model.intercept_}")
print(f"m: {model.coef_}")
plt.plot(y_pred,'-g')

plt.legend(loc='upper left', prop={'size': 10}, frameon=False)
plt.xlabel('Jornadas')
plt.ylabel('Suma de goles')
plt.xticks(list(range(0,22)))
plt.yticks([0,100,200,300,400,500,600])

plt.savefig('mls_cumulativo_j{}.png'.format(jornadascompletas))
plt.show()
# Out:
# Regresión lineal de sumatoria de goles de locales
# R^2: 0.9993426326554903
# b: 25.256916996047494
# m: [21.1460654]
#
# Regresión lineal de sumatoria de goles de visitantes
# R^2: 0.9971828934383309
# b: 4.636363636363683
# m: [15.2107438]
#
# Regresión lineal de diferencia de goles por jornada
# R^2: 0.9676174730136033
# b: 20.620553359683797
# m: [5.9353216]
